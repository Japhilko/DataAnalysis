# %% [markdown]
# # Working with csv data in python
#
# first you have to import some modules

# %%
import pandas
from pandas import *

# %%
names=read_csv('https://raw.githubusercontent.com/Japhilko/DataAnalysis/master/data/RinneBSP.csv')

# %%
names
# Out:
#     Unnamed: 0                                            Geo  X2012Q1  \
# 0            1                                     BE:Belgium      1.0
# 1            2                                    BG:Bulgaria      3.9
# 2            3                              CZ:Czech Republic     -1.0
# 3            4                                     DK:Denmark      1.9
# 4            5                                     DE:Germany      1.5
# 5            6                                     EE:Estonia      6.2
# 6            7                                     IE:Ireland     -3.5
# 7            8                                      EL:Greece     -8.3
# 8            9                                       ES:Spain     -1.9
# 9           10                                      FR:France     -0.3
# 10          11                                     HR:Croatia     -0.9
# 11          12                                       IT:Italy     -3.3
# ...

# %% [markdown]
# https://www.youtube.com/watch?v=XkXXpaVpNSc

# %% [markdown]
# # How to add plots

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp')
plt.show()
# http://stackoverflow.com/questions/19410042/how-to-make-ipython-notebook-inline-matplotlib-graphics

# %% [markdown]
# # Draw random numbers

# %%
mu, sigma = 1,0.1
s = np.random.normal(mu, sigma, 1000)
s2 = np.random.normal(mu, sigma, 1000)
plt.plot(s,s2)
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.normal.html

# %% [markdown]
# # Include images from external sources

# %% [markdown]
# <img src="http://www.pyzo.org/_images/Python3-powered_hello-world.png">

# %% [markdown]
# ### Example code for python
# http://code.activestate.com/recipes/langs/python/?query_start=1
